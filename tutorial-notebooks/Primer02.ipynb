# %% [markdown]
# [Prev](Primer01.ipynb)
#
# DataJoint Primer. Section 2.
# # Defining a table

# %% [markdown]
# ## Some terminology
# DataJoint relies the *Relational Data Model* for organizing its data.
#
# The crux of the Relational Data Model is that all data are stored in simple **tables** with **rows** and **columns**.
#
# In more theoretical and academic settings, he tables are called **relations**, columns are **attributes**, and rows are **tuples**.  We may use boths sets of terms interchangeably.
#
# The tables are simple and may not be nested and can always be accessed directly without following paths of links.
#
# Groups of related tables are called **schemas**. The word **database** is synonymous to **schema** in this context and we may use them interchangeably.
#
# To summarize, when speaking about databases
# > "schema" == "database"
#
# > "relation" == "table"
#
# > "attribute" == "column"
#
# > "tuple" == "row"

# %% [markdown]
# ## Create a schema
# As described in Primer 0, I have all privileges to any schema that starts with `dimitri_`.
#
# Therefore, let me create a new schema for data about things in our lab.

# %%
import datajoint as dj
schema = dj.schema('dimitri_lab', locals())
# Out:
# DataJoint 0.2.1 (June 1, 2016)
# Loading local settings from /Users/dimitri/.datajoint_config.json

# %% [markdown]
# ## Create a table
# Now I will create a table in the database `dimitri_lab` by declaring a special Python class. For example, let's create the table `Person` to store information about people who work in our lab.

# %%
@schema
class Person(dj.Manual):
    definition = """   # members of the lab
    username : char(16)   # short unique name
    ----
    full_name : varchar(25)
    """

# %% [markdown]
# This defines a table with two columns `username` and `full_name`.
# ## Inserting data manually
# We can now enter single rows of data into `Person` one at a time using the `insert1` method:

# %%
Person().insert1(('dimitri', 'Dimitri Yatsenko'))
Person().insert1(dict(username='shan', full_name="Shan Shen"))

# %% [markdown]
# Or multiple rows at once using the `insert` method:

# %%
Person().insert((
    ('andreas', 'Andreas S. Tolias'),
    ('jake', 'Jacob Reimer'),
    ('fabee', 'Fabian Sinz'),
    {'full_name': 'Edgar Y. Walker', 'username': 'edgar'}
    ))

# %% [markdown]
# ## Previewing data
# You may get a preview of the contents of the table from the instance of its class:

# %%
Person()
# Out:
# username     full_name
# +----------+ +------------+
# andreas      Andreas S. Tol
# dimitri      Dimitri Yatsen
# edgar        Edgar Y. Walke
# fabee        Fabian Sinz
# jake         Jacob Reimer
# shan         Shan Shen
#  (6 tuples)

# %% [markdown]
# DataJoint will not allow entering two rows with the same `username` because it is the *primary key* of `Person`.
#
# The primary key attributes are listed above the separator `---` in the `definition` string.  Every row must have unique values in the primary key attributes.

# %%
Person().insert1(('jake', 'Jacob W'))
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-18-7f7f296cdca7> in <module>()
# ----> 1 Person().insert1(('jake', 'Jacob W'))
#
# /Users/dimitri/dev/datajoint-python/datajoint/base_relation.py in insert1(self, row, **kwargs)
#     123         :param row: Data record, a Mapping (like a dict), or a list or tuple with ordered values.
#     124         """
# --> 125         self.insert((row,), **kwargs)
#     126
#     127     def insert(self, rows, replace=False, ignore_errors=False, skip_duplicates=False):
#
# /Users/dimitri/dev/datajoint-python/datajoint/base_relation.py in insert(self, rows, replace, ignore_errors, skip_duplicates)
#     242                         fields='`,`'.join(field_list),
#     243                         placeholders=','.join('(' + ','.join(row['placeholders']) + ')' for row in rows)),
# --> 244                     args=list(itertools.chain.from_iterable((v for v in r['values'] if v is not None) for r in rows)))
#     245
#     246     def delete_quick(self):
#
# /Users/dimitri/dev/datajoint-python/datajoint/connection.py in query(self, query, args, as_dict)
#     106         # Log the query
#     107         logger.debug("Executing SQL:" + query[0:300])
# --> 108         cur.execute(query, args)
#     109
#     110         return cur
#
# /usr/local/lib/python3.5/site-packages/pymysql/cursors.py in execute(self, query, args)
#     156         query = self.mogrify(query, args)
#     157
# --> 158         result = self._query(query)
#     159         self._executed = query
#     160         return result
#
# /usr/local/lib/python3.5/site-packages/pymysql/cursors.py in _query(self, q)
#     306         conn = self._get_db()
#     307         self._last_executed = q
# --> 308         conn.query(q)
#     309         self._do_get_result()
#     310         return self.rowcount
#
# /usr/local/lib/python3.5/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     818                 sql = sql.encode(self.encoding, 'surrogateescape')
#     819         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 820         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     821         return self._affected_rows
#     822
#
# /usr/local/lib/python3.5/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1000         else:
#    1001             result = MySQLResult(self)
# -> 1002             result.read()
#    1003         self._result = result
#    1004         if result.server_status is not None:
#
# /usr/local/lib/python3.5/site-packages/pymysql/connections.py in read(self)
#    1283     def read(self):
#    1284         try:
# -> 1285             first_packet = self.connection._read_packet()
#    1286
#    1287             if first_packet.is_ok_packet():
#
# /usr/local/lib/python3.5/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     964
#     965         packet = packet_type(buff, self.encoding)
# --> 966         packet.check_error()
#     967         return packet
#     968
#
# /usr/local/lib/python3.5/site-packages/pymysql/connections.py in check_error(self)
#     392             errno = self.read_uint16()
#     393             if DEBUG: print("errno =", errno)
# --> 394             err.raise_mysql_exception(self._data)
#     395
#     396     def dump(self):
#
# /usr/local/lib/python3.5/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     118 def raise_mysql_exception(data):
#     119     errinfo = _get_error_info(data)
# --> 120     _check_mysql_exception(errinfo)
#
# /usr/local/lib/python3.5/site-packages/pymysql/err.py in _check_mysql_exception(errinfo)
#     110     errorclass = error_map.get(errno, None)
#     111     if errorclass:
# --> 112         raise errorclass(errno, errorvalue)
#     113
#     114     # couldn't find the right error number
#
# IntegrityError: (1062, "Duplicate entry 'jake' for key 'PRIMARY'")

# %% [markdown]
# ## Deleting all rows from a table

# %% [markdown]
# The `delete` method deletes all rows from the table:

# %%
Person().delete()
# Out:
# The contents of the following tables are about to be deleted:
# `dimitri_lab`.`person` (6 tuples)
# Proceed? [yes, No]: yes
# Done

# %%
Person()
# Out:
# username     full_name
# +----------+ +-----------+
#  (0 tuples)

# %% [markdown]
# ## Dropping the table
# Deleting all rows from the table still leaves the empy table in the database.
# The `drop` method removes the table from the database:

# %%
Person().drop()
# Out:
# `dimitri_lab`.`person` (0 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.

# %% [markdown]
# It suggests to restart the Python kernel.  This is because the class `Person` remains but its table is no longer defined in the database. Using the `Person` class after dropping its table will cause errors (see below).  When the class is defined again, its table will be created again from its `definition` string.  However, if the table is not dropped, the new class will use the existing table and its `definition` string will have no effect.

# %%
Person()
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# /Users/dimitri/dev/datajoint-python/datajoint/relational_operand.py in _repr_html_(self)
#     360     def _repr_html_(self):
#     361         limit = config['display.limit']
# --> 362         rel = self.proj(*self.heading.non_blobs)  # project out blobs
#     363         columns = rel.heading.names
#     364         info = self.heading.table_info
#
# /Users/dimitri/dev/datajoint-python/datajoint/base_relation.py in heading(self)
#      51             self._heading = Heading()  # instance-level heading
#      52         if not self._heading:  # lazy loading of heading
# ---> 53             self._heading.init_from_database(self.connection, self.database, self.table_name)
#      54         return self._heading
#      55
#
# /Users/dimitri/dev/datajoint-python/datajoint/heading.py in init_from_database(self, conn, database, table_name)
#     121             table_name=table_name, database=database), as_dict=True).fetchone()
#     122         if info is None:
# --> 123             raise DataJointError('The table is not defined.')
#     124         self.table_info = {k.lower(): v for k, v in info.items()}
#     125
#
# DataJointError: The table is not defined.
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /usr/local/lib/python3.5/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /usr/local/lib/python3.5/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /usr/local/lib/python3.5/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     692     """A pprint that just redirects to the normal repr function."""
#     693     # Find newlines and replace them with p.break_()
# --> 694     output = repr(obj)
#     695     for idx,output_line in enumerate(output.splitlines()):
#     696         if idx:
#
# /Users/dimitri/dev/datajoint-python/datajoint/relational_operand.py in __repr__(self)
#     337                 ret += ' & %r' % self._restrictions
#     338         else:
# --> 339             rel = self.proj(*self.heading.non_blobs)  # project out blobs
#     340             limit = config['display.limit']
#     341             width = config['display.width']
#
# /Users/dimitri/dev/datajoint-python/datajoint/base_relation.py in heading(self)
#      51             self._heading = Heading()  # instance-level heading
#      52         if not self._heading:  # lazy loading of heading
# ---> 53             self._heading.init_from_database(self.connection, self.database, self.table_name)
#      54         return self._heading
#      55
#
# /Users/dimitri/dev/datajoint-python/datajoint/heading.py in init_from_database(self, conn, database, table_name)
#     121             table_name=table_name, database=database), as_dict=True).fetchone()
#     122         if info is None:
# --> 123             raise DataJointError('The table is not defined.')
#     124         self.table_info = {k.lower(): v for k, v in info.items()}
#     125
#
# DataJointError: The table is not defined.

# %% [markdown]
# # A closer look
#
# ## What makes a relation class
# - Class `Person` is decorated with the `schema` object created earlier. It links the table to the database.
# - Class `Person` inherits from `dj.Manual`, which indicates that data will be entered into `Person` manually.  We will discuss automatically populated tables in future sections.
# - Class `Person` defines the multiline string property `definition`, which defines the attributes (columns) of the table.
# - The class name **must** be in CamelCase and can only contain alphanumerical characters (underscores are not allowed).  This is important because datajoint converts the class name into the corresponding table name in the database.
#
# ## Format of the table definition string
# The first line beginning with a `#` describes the contents of the table.
# Each of the subsequent lines defines an attribute (column) of the table in the format
# > `attribute_name : type    # comment`
#
# All attribute names must be in lowercase, must start with a letter and can only contain alphanumerical characters and underscores.
#
# The separator
# > `----`
#
# comprises three or more dashes and separates the **primary key** attributes above from the **dependent attributes** below.
#
# The primary key attributes uniquely identify each row in the table; the table cannot contain two rows with the same values of the primary key attributes.
#
# ## Attribute types
# The attribute types are MySQL data types and are summarized here http://datajoint.github.io/datatypes/.
#
# Most commonly used in datajoint are
# - signed integers: ** `tinyint`, `smallint`, `int`, `bigint`  **
# - unsigned integers: ** `tinyint unsigned`, `smallint unsigned`, `int unsigned`, `bigint unsigned` **
# - floating-point and fixed-point fractional numbers: **`float`, `double`, `decimal`**
# - enumeration: **`enum`**
# - true/false **`boolean`**
# - strings **`char`, `varchar`**
# - dates and times **`date`, `timestamp`**
# - arbitrary things such as images, traces, etc: **`longblob`**

# %% [markdown]
# [Next](Primer03.ipynb)
